# %%
import pandas as pd
import json
import os
import matplotlib.cm
import pickle
from collections import defaultdict

# %% [markdown]
# # Each Audio Clip is used in multiple places.
#
# Map each audio to all characters that use that clip.
#
# Map each audio to all descriptions that use that clip.

# %%
with open('./duplicate-sounds-lookup.pkl', 'rb') as f:
    audio_groups = pickle.load(f)
    audio_groups = [[f[len('./tmp/'):] for f in group] for group in audio_groups]
    
audio_files = [
    file
    for group in audio_groups
    for file in group
]
print('Game has', len(audio_files), 'audio files. And', len(audio_groups), 'unique audio sounds.')
# Out:
# Game has 103945 audio files. And 11019 unique audio sounds.

# %%
print('Every sound belongs to one-to-many characters')

CHARS = {
    'brave': 'Hero',
    'buddy': 'Banjo & Kazooie',
    'captain': 'Captain Falcon',
    'dedede': 'King Dedede',
    'demon': 'Kazuya',
    'dolly': 'Terry',
    'donkey': 'Donkey Kong',
    'diddy': 'Diddy Kong',
    'duckhunt': 'Duck Hunt',
    'edge': 'Sephiroth',
    'eflame': 'Pyra / Mithra',
    'element': 'Pyra / Mithra',
    'elight': 'Pyra / Mithra',
    'gamewatch': 'Mr. Game & Watch',
    'ganon': 'Ganondorf',
    'gaogaen': 'Inceneroar',
    'gekkouga': 'Greninja',
    'jack': 'Joker',
    'kamui': 'Corrin',
    'koopa': 'Bowser',
    'koopag': 'Bowser',  # Mega-Bowser
    'koopajr': 'Bowser Jr.',
    'krool': 'King K. Rool',
    'littlemac': 'Little Mac',
    'mariod': 'Dr. Mario',
    'master': 'Byleth',
    'metaknight': 'Meta Knight',
    'mewtwo': 'Mewtwo',
    'mii': 'Mii',
    'miienemyf': 'Mii',
    'miienemyg': 'Mii',
    'miienemys': 'Mii',
    'miifighter': 'Mii',
    'miigunner': 'Mii',
    'miiswordsman': 'Mii',
    'murabito': 'Villager',
    'nana': 'Ice Climbers',
    'popo': 'Ice Climbers',
    'packun': 'Piranha Plant',
    'pacman': 'Pac Man',
    'pfushigisou': 'Pokemon Trainer',
    'plizardon': 'Pokemon Trainer',
    'ptrainer': 'Pokemon Trainer',
    'pzenigame': 'Pokemon Trainer',
    'pickel': 'Steve / Alex',
    'pikmin': 'Olimar',
    'pitb': 'Dark Pit',
    'purin': 'Jigglypuff',
    'reflet': 'Robin',
    'robot': 'Rob',
    'rockman': 'Mega Man',
    'rosetta': 'Rosalina & Luma',
    'samusd': 'Dark Samus',
    'shizue': 'Isabelle',
    'szerosuit': 'Zero Suit Samus',
    'tantan': 'Min Min',
    'toonlink': 'Toon Link',
    'trail': 'Sora',
    'wiifit': 'Wii Fit Trainer',
    'younglink': 'Young Link',
}

def file_to_character(file):
    result = file[3:].split('---', 1)[0].split('_')[0]
    if result in CHARS:
        return CHARS[result]
    return result[0].upper() + result[1:]


NUMS = ''.join(str(i) for i in range(10))
def file_to_desc(file):
    result = file[3:].split('---', 1)[1].split('_')[2].strip(NUMS)
    if result == 'sheildguard':
        return 'shieldguard'
    return result


file_to_characters = {}
file_to_tags = {}
for group in audio_groups:
    characters_in_group = set()
    tags = set()
    for file in group:
        characters_in_group.add(file_to_character(file))
        tags.add(file_to_desc(file))
        
    for file in group:
        file_no_ext = file.split('.', 1)[0]
        file_to_characters[file_no_ext] = list(characters_in_group)
    for file in group:
        file_no_ext = file.split('.', 1)[0]
        file_to_tags[file_no_ext] = list(tags)
# Out:
# Every sound belongs to one-to-many characters

# %%
pd.set_option('max_rows', 10000)
print('Audio clips per action')
pd.Series(file_to_tags.values()).apply(pd.Series).stack().value_counts()
# Out:
# Audio clips per action
# special                   22226
# step                       6709
# appeal                     5882
# attackair                  5355
# smash                      4781
# win                        4580
# swing                      4355
# final                      3862
# attackhard                 3800
# jump01.idsp                2859
# .idsp                      2504
# dash                       2504
# throw                      2394
# jump02.idsp                2336
# final02.idsp               2118
# landing01.idsp             2068
# final03.idsp               2048
# escapeair.idsp             2004
# escape.idsp                2003
# final04.idsp               1983
# damage                     1932
# attack01.idsp              1887
# missfoot01.idsp            1878
# attack03.idsp              1878
# furasleep.idsp             1869
# attack02.idsp              1851
# attack05.idsp              1851
# furafura.idsp              1851
# win01.idsp                 1845
# attack06.idsp              1842
# knockout.idsp              1842
# damagefly02.idsp           1833
# win02.idsp                 1829
# swimup.idsp                1824
# attack04.idsp              1819
# damagefly01.idsp           1819
# ottotto.idsp               1819
# passive.idsp               1815
# damage02.idsp              1810
# attack07.idsp              1806
# missfoot02.idsp            1788
# damage01.idsp              1779
# heavyget.idsp              1779
# cliffcatch.idsp            1778
# win03.idsp                 1755
# appear02.idsp              1737
# appeal02.idsp              1619
# appeal01.idsp              1610
# appeal03.idsp              1554
# final06.idsp               1521
# attackdash.idsp            1493
# wakeup.idsp                1464
# final01.idsp               1290
# catch.idsp                 1244
# copy                       1236
# damage03.idsp              1189
# wad                        1136
# special05.idsp             1130
# win09.idsp                 1118
# landing                    1117
# ingame05.idsp              1110
# win05.idsp                 1110
# ingame14.idsp              1108
# win14.idsp                 1108
# combo03.idsp               1107
# combo01.idsp               1107
# combo02.idsp               1107
# silent02.idsp              1100
# silent                     1100
# silent.idsp                1100
# ingame17.idsp              1100
# silent01.idsp              1100
# win12.idsp                 1100
# hide                       1100
# ingame09.idsp              1100
# win11.idsp                 1100
# silent03.idsp              1100
# ingame12.idsp              1100
# ingame11.idsp              1100
# win17.idsp                 1100
# landing02.idsp             1060
# attack                     1019
# jump03.idsp                 948
# rise.idsp                   925
# squat.idsp                  899
# hit                         888
# appear01.idsp               806
# cheer.idsp                  803
# jump                        803
# crawing                     738
# landing03.idsp              698
# final05.idsp                634
# appear03.idsp               396
# cloth                       368
# attack100.idsp              344
# appear                      333
# attackdash01.idsp           329
# attackdash                  324
# wait                        297
# attackdash02.idsp           295
# wave                        288
# diver                       275
# throwcommand                270
#                             270
# attackstep2S                234
# final07.idsp                234
# escape                      229
# attackl                     225
# attack08.idsp               212
# attack09.idsp               185
# rise                        181
# superspecial                180
# Whip                        162
# attackstand21.idsp          153
# attackstand22.idsp          153
# attackstand1.idsp           153
# attacksquat4.idsp           153
# catch                       144
# win1.idsp                   135
# hammer                      135
# attack100end.idsp           126
# escapen.idsp                122
# appear.idsp                 119
# criticalhit.idsp            117
# kogeuge                     110
# finalhit                    108
# ball                        108
# final08.idsp                108
# win2.idsp                   108
# jumpround.idsp               99
# win3.idsp                    99
# ragedrive                    90
# tailswing.idsp               90
# final09.idsp                 90
# shoot                        83
# winged                       81
# squat                        80
# swordin.idsp                 72
# landing04.idsp               72
# escapeN.idsp                 72
# swish05.idsp                 63
# finala                       63
# swish09.idsp                 63
# swish06.idsp                 63
# jump04.idsp                  63
# swish11.idsp                 63
# swish08.idsp                 63
# swish07.idsp                 63
# swish10.idsp                 63
# cliffcatch01.idsp            59
# doyle                        56
# appeal04.idsp                55
# punch                        54
# swordin                      54
# attack10.idsp                54
# bell                         54
# appear04.idsp                54
# wear                         54
# hand                         54
# win04.idsp                   52
# escapeForesight01.idsp       50
# escapeForesight02.idsp       50
# turn                         46
# amb02.idsp                   45
# amb04.idsp                   45
# wear02.idsp                  45
# jump.idsp                    45
# finalb                       45
# change                       45
# hitground.idsp               45
# missfoot.idsp                45
# plunger                      45
# amb05.idsp                   45
# final10.idsp                 45
# amb01.idsp                   45
# gear                         45
# appeal.idsp                  45
# cliffjump.idsp               45
# finalstart.idsp              45
# machine                      45
# amb03.idsp                   45
# special01.idsp               36
# bata                         36
# special06.idsp               36
# horn                         36
# special07.idsp               36
# wear01.idsp                  36
# special03.idsp               36
# dog                          36
# special04.idsp               36
# shieldguard.idsp             36
# ryu                          36
# special09.idsp               36
# close                        36
# pk                           36
# escapeB.idsp                 36
# dragon                       36
# ken                          36
# special08.idsp               36
# swordpullout.idsp            36
# special10.idsp               36
# special02.idsp               36
# command                      36
# blasterhit.idsp              29
# final.idsp                   28
# squatb                       27
# book                         27
# ladderstep                   27
# sheildguard.idsp             27
# open                         27
# nailswing02.idsp             27
# down                         27
# escapeb.idsp                 27
# down.idsp                    27
# win06.idsp                   27
# escapeair                    27
# dead.idsp                    27
# spark                        27
# soubi                        27
# squatf                       27
# cardboard                    27
# guardoff.idsp                27
# guest                        27
# win08.idsp                   27
# win07.idsp                   27
# yoyo                         27
# clungthrown.idsp             27
# close.idsp                   27
# catch01.idsp                 27
# attackdash03.idsp            27
# leather                      27
# tailswing03.idsp             27
# spring                       27
# escapeForesight03.idsp       25
# wait04.idsp                  24
# wait02.idsp                  20
# wait01.idsp                  20
# wait03.idsp                  20
# appeal05.idsp                19
# throw.idsp                   18
# hip                          18
# win21.idsp                   18
# win20.idsp                   18
# bowsplit.idsp                18
# clungdiddy.idsp              18
# bell02.idsp                  18
# sleep                        18
# final15.idsp                 18
# jump05.idsp                  18
# batwithin02.idsp             18
# dragon.idsp                  18
# win19.idsp                   18
# guardon.idsp                 18
# ingame07.idsp                18
# scratchhit.idsp              18
# bell03.idsp                  18
# fireballhit.idsp             18
# spark03.idsp                 18
# guard                        18
# attackstep2.idsp             18
# cliffclimb.idsp              18
# appeal09.idsp                18
# ingame04.idsp                18
# ingame10.idsp                18
# guard.idsp                   18
# wood                         18
# duck                         18
# ingame08.idsp                18
# ragedrive.idsp               18
# bell01.idsp                  18
# win18.idsp                   18
# sliprise.idsp                18
# ingame06.idsp                18
# entry                        18
# ingame13.idsp                18
# ingame03.idsp                18
# miss.idsp                    18
# final01b.idsp                18
# ingame20.idsp                18
# catch02.idsp                 18
# win15.idsp                   18
# ingame19.idsp                18
# return.idsp                  18
# mp                           18
# escape02.idsp                18
# attacksquat1.idsp            18
# fire                         18
# ingame02.idsp                18
# clung.idsp                   18
# ingame01.idsp                18
# cloth01.idsp                 18
# spark02.idsp                 18
# win16.idsp                   18
# ingame18.idsp                18
# sleep.idsp                   18
# escapef                      18
# escapef.idsp                 18
# return                       18
# ingame15.idsp                18
# wait2.idsp                   18
# dokan.idsp                   18
# monado                       18
# ware01.idsp                  18
# manthit.idsp                 18
# cliffclimbquick.idsp         18
# finallast.idsp               18
# run.idsp                     18
# win13.idsp                   18
# final01a.idsp                18
# escapeairN.idsp              18
# ingame21.idsp                18
# ingame16.idsp                18
# win10.idsp                   18
# nailswing01.idsp             18
# smash.idsp                   18
# gun                          10
# appeal06.idsp                10
# wire                         10
# bell08.idsp                   9
# loveisblue                    9
# attackbomb.idsp               9
# appear05.idsp                 9
# commandclick.idsp             9
# wecked                        9
# metal02.idsp                  9
# throw05.idsp                  9
# bite                          9
# damage07.idsp                 9
# down01.idsp                   9
# inkchargestart.idsp           9
# escapeFB.idsp                 9
# bell04.idsp                   9
# hoshikie.idsp                 9
# call01.idsp                   9
# throw02.idsp                  9
# call02.idsp                   9
# react                         9
# win.idsp                      9
# tonguecatch.idsp              9
# throw01.idsp                  9
# groan.idsp                    9
# call03.idsp                   9
# catchloop.idsp                9
# escape01.idsp                 9
# dead02.idsp                   9
# attackappeal03.idsp           9
# throw13.idsp                  9
# criffrise.idsp                9
# bowcombine.idsp               9
# handclap                      9
# bell05.idsp                   9
# damage04.idsp                 9
# crownappear.idsp              9
# commandsuccess.idsp           9
# throw12.idsp                  9
# attackstep2f.idsp             9
# final14.idsp                  9
# ware04.idsp                   9
# wait3.idsp                    9
# stamina                       9
# final12.idsp                  9
# clap.idsp                     9
# attackstep2L                  9
# attackappeal02.idsp           9
# throw10.idsp                  9
# entry.idsp                    9
# throw04.idsp                  9
# magic11.idsp                  9
# attackappeal05.idsp           9
# down02.idsp                   9
# smash04.idsp                  9
# futtobi01.idsp                9
# tankempty.idsp                9
# smash08.idsp                  9
# damage05.idsp                 9
# shieldguard                   9
# futtobi02.idsp                9
# wing.idsp                     9
# hit01.idsp                    9
# swordgroundhit.idsp           9
# throw03.idsp                  9
# attack13.idsp                 9
# magic01.idsp                  9
# capture.idsp                  9
# smash06.idsp                  9
# escapeF.idsp                  9
# wait1.idsp                    9
# attack11.idsp                 9
# escapeN01.idsp                9
# sliding.idsp                  9
# attackappeal04.idsp           9
# egg                           9
# final11.idsp                  9
# throw08.idsp                  9
# sad.idsp                      9
# hit02.idsp                    9
# damagefly03.idsp              9
# damage08.idsp                 9
# rage.idsp                     9
# criff                         9
# gliderun.idsp                 9
# falldead.idsp                 9
# rounddash.idsp                9
# call04.idsp                   9
# roundholdloop.idsp            9
# criffjump.idsp                9
# subweaponready.idsp           9
# throw07.idsp                  9
# gordo                         9
# overheat.idsp                 9
# throw06.idsp                  9
# final17.idsp                  9
# attack12.idsp                 9
# jump07.idsp                   9
# tailhit.idsp                  9
# smash07.idsp                  9
# smash03.idsp                  9
# rage01.idsp                   9
# escapeN02.idsp                9
# dead01.idsp                   9
# escapecliff.idsp              9
# handclap.idsp                 9
# metal.idsp                    9
# arm                           9
# angry.idsp                    9
# win03b.idsp                   9
# galaxy.idsp                   9
# bell06.idsp                   9
# whistle.idsp                  9
# winged02.idsp                 9
# hammermax.idsp                9
# slipattack.idsp               9
# chichi.idsp                   9
# winged03.idsp                 9
# landingbody.idsp              9
# tailswing02.idsp              9
# damage09.idsp                 9
# airshot.idsp                  9
# rockbuster.idsp               9
# throw09.idsp                  9
# spark.idsp                    9
# throw11.idsp                  9
# smash05.idsp                  9
# jet.idsp                      9
# rebirth.idsp                  9
# magic10.idsp                  9
# damage06.idsp                 9
# bell07.idsp                   9
# call05.idsp                   9
# open.idsp                     9
# attackappeal01.idsp           9
# jump06.idsp                   9
# dtype: int64

# %%
pd.set_option('max_rows', 10000)
print('Audio clips per character')
pd.Series(file_to_characters.values()).apply(pd.Series).stack().value_counts()
# Out:
# Audio clips per character
# Pyra / Mithra       9834
# Pokemon Trainer     4032
# Mii                 3812
# Joker               3295
# Bayonetta           2779
# Banjo & Kazooie     2758
# Cloud               2754
# Pikachu             2729
# Young Link          2621
# Min Min             2585
# Kazuya              2585
# Robin               2522
# Lucas               2504
# Ice Climbers        2475
# Meta Knight         2423
# Bowser              2405
# Greninja            2333
# Little Mac          2315
# Pit                 2261
# Ness                2261
# Lucario             2252
# Bowser Jr.          2232
# Luigi               2216
# Wii Fit Trainer     2190
# Hero                2169
# Wario               2126
# Kirby               2118
# King Dedede         2117
# Chrom               2090
# Ken                 2088
# Dark Samus          2081
# Yoshi               2072
# Diddy Kong          2072
# Zero Suit Samus     2027
# Jigglypuff          1991
# Donkey Kong         1982
# Mewtwo              1973
# Roy                 1971
# Richter             1944
# Simon               1935
# Olimar              1911
# Ganondorf           1901
# Ryu                 1900
# Captain Falcon      1874
# Sonic               1847
# Lucina              1845
# Marth               1836
# Byleth              1760
# Terry               1746
# Mr. Game & Watch    1739
# Sora                1726
# Sephiroth           1674
# Pichu               1647
# Peach               1602
# Daisy               1593
# Link                1575
# Inceneroar          1575
# Toon Link           1566
# Mario               1406
# Steve / Alex        1380
# Shulk               1350
# King K. Rool        1341
# Corrin              1278
# Snake               1233
# Dark Pit            1233
# Dr. Mario           1224
# Isabelle            1134
# Palutena            1089
# Ike                 1087
# Rob                 1080
# Zelda               1035
# Duck Hunt           1008
# Falco                994
# Villager             991
# Piranha Plant        972
# Rosalina & Luma      963
# Inkling              963
# Pac Man              963
# Wolf                 954
# Samus                918
# Ridley               900
# Sheik                819
# Fox                  812
# Mega Man             531
# dtype: int64

# %%
print('Voice channels & Sound-effects are not grouped together (except with the empty sound group)')
len([g for g in audio_groups if any(f.startswith('se_') for f in g) and any(f.startswith('vc_') for f in g)])
# Out:
# Voice channels & Sound-effects are not grouped together (except with the empty sound group)
# 1

# %% [markdown]
# # Enrich T-SNE Output with Characters + Tags + Colors

# %%
with open('./smash-audio-1d.json') as f:
    smash_1d = pd.DataFrame(json.load(f))

with open('./smash-audio-2d.json') as f:
    smash_2d = pd.DataFrame(json.load(f))

smash_2d.head()
# Out:
#                                                 path  \
# 0  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 1  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 2  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 3  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 4  /Users/ahmedelzeiny/Documents/practice/smash-a...
#
#                                        point
# 0   [0.5696493491718344, 0.4781135807713881]
# 1   [0.5059782610530396, 0.9770618915967754]
# 2   [0.3650738872352471, 0.6661001788908766]
# 3   [0.9113770948051566, 0.5967620419447662]
# 4  [0.5453826343644428, 0.12557459152143538]

# %%
smash_2d['file'] = smash_2d['path'].apply(os.path.basename)
smash_2d['x'] = smash_2d['point'].apply(lambda o: o[0])
smash_2d['y'] = smash_2d['point'].apply(lambda o: o[1])
smash_2d.head()
# Out:
#                                                 path  \
# 0  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 1  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 2  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 3  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 4  /Users/ahmedelzeiny/Documents/practice/smash-a...
#
#                                        point  \
# 0   [0.5696493491718344, 0.4781135807713881]
# 1   [0.5059782610530396, 0.9770618915967754]
# 2   [0.3650738872352471, 0.6661001788908766]
# 3   [0.9113770948051566, 0.5967620419447662]
# 4  [0.5453826343644428, 0.12557459152143538]
#
#                                              file         x         y
# 0  vc_mii_m06_warrior_low---vc_mii_finalstart.wav  0.569649  0.478114
# 1           vc_dedede_cheer---vc_dedede_cheer.wav  0.505978  0.977062
# 2             se_link---se_link_dash_soubi_02.wav  0.365074  0.666100
# 3              se_jack---se_jack_dash_turn_ft.wav  0.911377  0.596762
# 4                   se_cloud---se_cloud_win02.wav  0.545383  0.125575

# %%
cmap = matplotlib.cm.get_cmap('viridis')
smash_2d['color_scale'] = smash_2d.merge(smash_1d, suffixes=('_2d', ''), on='path')['x']
smash_2d['hex'] = smash_2d['color_scale'].apply(lambda c: matplotlib.colors.rgb2hex(cmap(c)))
smash_2d['chars'] = smash_2d['file'].apply(lambda f: file_to_characters[f[:-len('.wav')]])
smash_2d['tags'] = smash_2d['file'].apply(lambda f: file_to_tags[f[:-len('.wav')]])
smash_2d.head()
# Out:
#                                                 path  \
# 0  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 1  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 2  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 3  /Users/ahmedelzeiny/Documents/practice/smash-a...
# 4  /Users/ahmedelzeiny/Documents/practice/smash-a...
#
#                                        point  \
# 0   [0.5696493491718344, 0.4781135807713881]
# 1   [0.5059782610530396, 0.9770618915967754]
# 2   [0.3650738872352471, 0.6661001788908766]
# 3   [0.9113770948051566, 0.5967620419447662]
# 4  [0.5453826343644428, 0.12557459152143538]
#
#                                              file         x         y  \
# 0  vc_mii_m06_warrior_low---vc_mii_finalstart.wav  0.569649  0.478114
# 1           vc_dedede_cheer---vc_dedede_cheer.wav  0.505978  0.977062
# 2             se_link---se_link_dash_soubi_02.wav  0.365074  0.666100
# 3              se_jack---se_jack_dash_turn_ft.wav  0.911377  0.596762
# 4                   se_cloud---se_cloud_win02.wav  0.545383  0.125575
#
#    color_scale      hex          chars               tags
# 0     0.569649  #1fa188          [Mii]  [finalstart.idsp]
# 1     0.505978  #20928c  [King Dedede]       [cheer.idsp]
# 2     0.365074  #2d708e         [Link]    [dash, landing]
# 3     0.911377  #c5e021        [Joker]             [dash]
# 4     0.545383  #1e9b8a        [Cloud]       [win02.idsp]

# %%
with open('sounds_of_smash.json', 'w') as f:
    output_json = smash_2d[['file', 'x', 'y', 'hex', 'chars', 'tags']].to_dict('records')
    json.dump(output_json, f)

# %% [markdown]
# # Explore file directory structure

# %%
dirs = defaultdict(list)
for file in audio_files:
    fdir, fname = file.split('---', 1)
    dirs[fdir].append(fname)

# %%
sorted(dirs.keys(), key=lambda s: s[3:])
# Out:
# ['se_bayonetta',
#  'vc_bayonetta',
#  'se_bayonetta_c00',
#  'vc_bayonetta_c00',
#  'se_bayonetta_c01',
#  'vc_bayonetta_c01',
#  'se_bayonetta_c02',
#  'vc_bayonetta_c02',
#  'se_bayonetta_c03',
#  'vc_bayonetta_c03',
#  'se_bayonetta_c04',
#  'vc_bayonetta_c04',
#  'se_bayonetta_c05',
#  'vc_bayonetta_c05',
#  'se_bayonetta_c06',
#  'vc_bayonetta_c06',
#  'se_bayonetta_c07',
#  'vc_bayonetta_c07',
#  'vc_bayonetta_cheer',
#  'vc_bayonetta_cheer_c00',
#  'vc_bayonetta_cheer_c01',
#  'vc_bayonetta_cheer_c02',
#  'vc_bayonetta_cheer_c03',
#  'vc_bayonetta_cheer_c04',
#  'vc_bayonetta_cheer_c05',
#  'vc_bayonetta_cheer_c06',
#  'vc_bayonetta_cheer_c07',
#  'se_brave',
#  'vc_brave',
#  'se_brave_c00',
#  'vc_brave_c00',
#  'se_brave_c01',
#  'vc_brave_c01',
#  'se_brave_c02',
#  'vc_brave_c02',
#  'se_brave_c03',
#  'vc_brave_c03',
#  'se_brave_c04',
#  'vc_brave_c04',
#  'se_brave_c05',
#  'vc_brave_c05',
#  'se_brave_c06',
#  'vc_brave_c06',
#  'se_brave_c07',
#  'vc_brave_c07',
#  'vc_brave_cheer',
#  'vc_brave_cheer_c00',
#  'vc_brave_cheer_c01',
#  'vc_brave_cheer_c02',
#  'vc_brave_cheer_c03',
#  'vc_brave_cheer_c04',
#  'vc_brave_cheer_c05',
#  'vc_brave_cheer_c06',
#  'vc_brave_cheer_c07',
#  'se_buddy',
#  'vc_buddy',
#  'se_buddy_c00',
#  'vc_buddy_c00',
#  'se_buddy_c01',
#  'vc_buddy_c01',
#  'se_buddy_c02',
#  'vc_buddy_c02',
#  'se_buddy_c03',
#  'vc_buddy_c03',
#  'se_buddy_c04',
#  'vc_buddy_c04',
#  'se_buddy_c05',
#  'vc_buddy_c05',
#  'se_buddy_c06',
#  'vc_buddy_c06',
#  'se_buddy_c07',
#  'vc_buddy_c07',
#  'vc_buddy_cheer',
#  'vc_buddy_cheer_c00',
#  'vc_buddy_cheer_c01',
#  'vc_buddy_cheer_c02',
#  'vc_buddy_cheer_c03',
#  'vc_buddy_cheer_c04',
#  'vc_buddy_cheer_c05',
#  'vc_buddy_cheer_c06',
#  'vc_buddy_cheer_c07',
#  'se_captain',
#  'vc_captain',
#  'se_captain_c00',
#  'vc_captain_c00',
#  'se_captain_c01',
#  'vc_captain_c01',
#  'se_captain_c02',
#  'vc_captain_c02',
#  'se_captain_c03',
#  'vc_captain_c03',
#  'se_captain_c04',
#  'vc_captain_c04',
#  'se_captain_c05',
#  'vc_captain_c05',
#  'se_captain_c06',
#  'vc_captain_c06',
#  'se_captain_c07',
#  'vc_captain_c07',
#  'vc_captain_cheer',
#  'vc_captain_cheer_c00',
#  'vc_captain_cheer_c01',
#  'vc_captain_cheer_c02',
#  'vc_captain_cheer_c03',
#  'vc_captain_cheer_c04',
#  'vc_captain_cheer_c05',
#  'vc_captain_cheer_c06',
#  'vc_captain_cheer_c07',
#  'se_chrom',
#  'vc_chrom',
#  'se_chrom_c00',
#  'vc_chrom_c00',
#  'se_chrom_c01',
#  'vc_chrom_c01',
#  'se_chrom_c02',
#  'vc_chrom_c02',
#  'se_chrom_c03',
#  'vc_chrom_c03',
#  'se_chrom_c04',
#  'vc_chrom_c04',
#  'se_chrom_c05',
#  'vc_chrom_c05',
#  'se_chrom_c06',
#  'vc_chrom_c06',
#  'se_chrom_c07',
#  'vc_chrom_c07',
#  'vc_chrom_cheer',
#  'vc_chrom_cheer_c00',
#  'vc_chrom_cheer_c01',
#  'vc_chrom_cheer_c02',
#  'vc_chrom_cheer_c03',
#  'vc_chrom_cheer_c04',
#  'vc_chrom_cheer_c05',
#  'vc_chrom_cheer_c06',
#  'vc_chrom_cheer_c07',
#  'se_cloud',
#  'vc_cloud',
#  'se_cloud_c00',
#  'vc_cloud_c00',
#  'se_cloud_c01',
#  'vc_cloud_c01',
#  'se_cloud_c01_append',
#  'vc_cloud_c01_append',
#  'se_cloud_c02',
#  'vc_cloud_c02',
#  'se_cloud_c03',
#  'vc_cloud_c03',
#  'se_cloud_c04',
#  'vc_cloud_c04',
#  'se_cloud_c05',
#  'vc_cloud_c05',
#  'se_cloud_c06',
#  'vc_cloud_c06',
#  'se_cloud_c07',
#  'vc_cloud_c07',
#  'vc_cloud_cheer',
#  'vc_cloud_cheer_c00',
#  'vc_cloud_cheer_c01',
#  'vc_cloud_cheer_c02',
#  'vc_cloud_cheer_c03',
#  'vc_cloud_cheer_c04',
#  'vc_cloud_cheer_c05',
#  'vc_cloud_cheer_c06',
#  'vc_cloud_cheer_c07',
#  'se_daisy',
#  'vc_daisy',
#  'se_daisy_c00',
#  'vc_daisy_c00',
#  'se_daisy_c01',
#  'vc_daisy_c01',
#  'se_daisy_c02',
#  'vc_daisy_c02',
#  'se_daisy_c03',
#  'vc_daisy_c03',
#  'se_daisy_c04',
#  'vc_daisy_c04',
#  'se_daisy_c05',
#  'vc_daisy_c05',
#  'se_daisy_c06',
#  'vc_daisy_c06',
#  'se_daisy_c07',
#  'vc_daisy_c07',
#  'vc_daisy_cheer',
#  'vc_daisy_cheer_c00',
#  'vc_daisy_cheer_c01',
#  'vc_daisy_cheer_c02',
#  'vc_daisy_cheer_c03',
#  'vc_daisy_cheer_c04',
#  'vc_daisy_cheer_c05',
#  'vc_daisy_cheer_c06',
#  'vc_daisy_cheer_c07',
#  'se_dedede',
#  'vc_dedede',
#  'se_dedede_c00',
#  'vc_dedede_c00',
#  'se_dedede_c01',
#  'vc_dedede_c01',
#  'se_dedede_c02',
#  'vc_dedede_c02',
#  'se_dedede_c03',
#  'vc_dedede_c03',
#  'se_dedede_c04',
#  'vc_dedede_c04',
#  'se_dedede_c05',
#  'vc_dedede_c05',
#  'se_dedede_c06',
#  'vc_dedede_c06',
#  'se_dedede_c07',
#  'vc_dedede_c07',
#  'vc_dedede_cheer',
#  'vc_dedede_cheer_c00',
#  'vc_dedede_cheer_c01',
#  'vc_dedede_cheer_c02',
#  'vc_dedede_cheer_c03',
#  'vc_dedede_cheer_c04',
#  'vc_dedede_cheer_c05',
#  'vc_dedede_cheer_c06',
#  'vc_dedede_cheer_c07',
#  'vc_demon',
#  'se_demon',
#  'vc_demon_c00',
#  'se_demon_c00',
#  'vc_demon_c01',
#  'se_demon_c01',
#  'vc_demon_c02',
#  'se_demon_c02',
#  'vc_demon_c03',
#  'se_demon_c03',
#  'vc_demon_c04',
#  'se_demon_c04',
#  'vc_demon_c05',
#  'se_demon_c05',
#  'vc_demon_c06',
#  'se_demon_c06',
#  'vc_demon_c07',
#  'se_demon_c07',
#  'vc_demon_cheer',
#  'vc_demon_cheer_c00',
#  'vc_demon_cheer_c01',
#  'vc_demon_cheer_c02',
#  'vc_demon_cheer_c03',
#  'vc_demon_cheer_c04',
#  'vc_demon_cheer_c05',
#  'vc_demon_cheer_c06',
#  'vc_demon_cheer_c07',
#  'se_diddy',
#  'vc_diddy',
#  'se_diddy_c00',
#  'vc_diddy_c00',
#  'se_diddy_c01',
#  'vc_diddy_c01',
#  'se_diddy_c02',
#  'vc_diddy_c02',
#  'se_diddy_c03',
#  'vc_diddy_c03',
#  'se_diddy_c04',
#  'vc_diddy_c04',
#  'se_diddy_c05',
#  'vc_diddy_c05',
#  'se_diddy_c06',
#  'vc_diddy_c06',
#  'se_diddy_c07',
#  'vc_diddy_c07',
#  'vc_diddy_cheer',
#  'vc_diddy_cheer_c00',
#  'vc_diddy_cheer_c01',
#  'vc_diddy_cheer_c02',
#  'vc_diddy_cheer_c03',
#  'vc_diddy_cheer_c04',
#  'vc_diddy_cheer_c05',
#  'vc_diddy_cheer_c06',
#  'vc_diddy_cheer_c07',
#  'se_dolly',
#  'vc_dolly',
#  'se_dolly_c00',
#  'vc_dolly_c00',
#  'se_dolly_c01',
#  'vc_dolly_c01',
#  'se_dolly_c02',
#  'vc_dolly_c02',
#  'se_dolly_c03',
#  'vc_dolly_c03',
#  'se_dolly_c04',
#  'vc_dolly_c04',
#  'se_dolly_c05',
#  'vc_dolly_c05',
#  'se_dolly_c06',
#  'vc_dolly_c06',
#  'se_dolly_c07',
#  'vc_dolly_c07',
#  'vc_dolly_cheer',
#  'vc_dolly_cheer_c00',
#  'vc_dolly_cheer_c01',
#  'vc_dolly_cheer_c02',
#  'vc_dolly_cheer_c03',
#  'vc_dolly_cheer_c04',
#  'vc_dolly_cheer_c05',
#  'vc_dolly_cheer_c06',
#  'vc_dolly_cheer_c07',
#  'vc_donkey',
#  'se_donkey',
#  'vc_donkey_c00',
#  'se_donkey_c00',
#  'vc_donkey_c01',
#  'se_donkey_c01',
#  'vc_donkey_c02',
#  'se_donkey_c02',
#  'vc_donkey_c03',
#  'se_donkey_c03',
#  'vc_donkey_c04',
#  'se_donkey_c04',
#  'vc_donkey_c05',
#  'se_donkey_c05',
#  'vc_donkey_c06',
#  'se_donkey_c06',
#  'vc_donkey_c07',
#  'se_donkey_c07',
#  'vc_donkey_cheer',
#  'vc_donkey_cheer_c00',
#  'vc_donkey_cheer_c01',
#  'vc_donkey_cheer_c02',
#  'vc_donkey_cheer_c03',
#  'vc_donkey_cheer_c04',
#  'vc_donkey_cheer_c05',
#  'vc_donkey_cheer_c06',
#  'vc_donkey_cheer_c07',
#  'se_duckhunt',
#  'vc_duckhunt',
#  'se_duckhunt_c00',
#  'vc_duckhunt_c00',
#  'se_duckhunt_c01',
#  'vc_duckhunt_c01',
#  'se_duckhunt_c02',
#  'vc_duckhunt_c02',
#  'se_duckhunt_c03',
#  'vc_duckhunt_c03',
#  'se_duckhunt_c04',
#  'vc_duckhunt_c04',
#  'se_duckhunt_c05',
#  'vc_duckhunt_c05',
#  'se_duckhunt_c06',
#  'vc_duckhunt_c06',
#  'se_duckhunt_c07',
#  'vc_duckhunt_c07',
#  'vc_duckhunt_cheer',
#  'vc_duckhunt_cheer_c00',
#  'vc_duckhunt_cheer_c01',
#  'vc_duckhunt_cheer_c02',
#  'vc_duckhunt_cheer_c03',
#  'vc_duckhunt_cheer_c04',
#  'vc_duckhunt_cheer_c05',
#  'vc_duckhunt_cheer_c06',
#  'vc_duckhunt_cheer_c07',
#  'se_edge',
#  'vc_edge',
#  'se_edge_c00',
#  'vc_edge_c00',
#  'se_edge_c01',
#  'vc_edge_c01',
#  'se_edge_c02',
#  'vc_edge_c02',
#  'se_edge_c03',
#  'vc_edge_c03',
#  'se_edge_c04',
#  'vc_edge_c04',
#  'se_edge_c05',
#  'vc_edge_c05',
#  'se_edge_c06',
#  'vc_edge_c06',
#  'se_edge_c07',
#  'vc_edge_c07',
#  'vc_edge_cheer',
#  'vc_edge_cheer_c00',
#  'vc_edge_cheer_c01',
#  'vc_edge_cheer_c02',
#  'vc_edge_cheer_c03',
#  'vc_edge_cheer_c04',
#  'vc_edge_cheer_c05',
#  'vc_edge_cheer_c06',
#  'vc_edge_cheer_c07',
#  'vc_eflame_c00',
#  'se_eflame_c00',
#  'vc_eflame_c01',
#  'se_eflame_c01',
#  'vc_eflame_c02',
#  'se_eflame_c02',
#  'vc_eflame_c03',
#  'se_eflame_c03',
#  'vc_eflame_c04',
#  'se_eflame_c04',
#  'vc_eflame_c05',
#  'se_eflame_c05',
#  'vc_eflame_c06',
#  'se_eflame_c06',
#  'vc_eflame_c07',
#  'se_eflame_c07',
#  'vc_eflame_cheer_c00',
#  'vc_eflame_cheer_c01',
#  'vc_eflame_cheer_c02',
#  'vc_eflame_cheer_c03',
#  'vc_eflame_cheer_c04',
#  'vc_eflame_cheer_c05',
#  'vc_eflame_cheer_c06',
#  'vc_eflame_cheer_c07',
#  'vc_element',
#  'se_element',
#  'vc_element_c00',
#  'se_element_c00',
#  'vc_element_c01',
#  'se_element_c01',
#  'vc_element_c02',
#  'se_element_c02',
#  'vc_element_c03',
#  'se_element_c03',
#  'vc_element_c04',
#  'se_element_c04',
#  'vc_element_c05',
#  'se_element_c05',
#  'vc_element_c06',
#  'se_element_c06',
#  'vc_element_c07',
#  'se_element_c07',
#  'vc_element_cheer',
#  'vc_element_cheer_c00',
#  'vc_element_cheer_c01',
#  'vc_element_cheer_c02',
#  'vc_element_cheer_c03',
#  'vc_element_cheer_c04',
#  'vc_element_cheer_c05',
#  'vc_element_cheer_c06',
#  'vc_element_cheer_c07',
#  'vc_elight_c00',
#  'se_elight_c00',
#  'vc_elight_c01',
#  'se_elight_c01',
#  'vc_elight_c02',
#  'se_elight_c02',
#  'vc_elight_c03',
#  'se_elight_c03',
#  'vc_elight_c04',
#  'se_elight_c04',
#  'vc_elight_c05',
#  'se_elight_c05',
#  'vc_elight_c06',
#  'se_elight_c06',
#  'vc_elight_c07',
#  'se_elight_c07',
#  'vc_elight_cheer_c00',
#  'vc_elight_cheer_c01',
#  'vc_elight_cheer_c02',
#  'vc_elight_cheer_c03',
#  'vc_elight_cheer_c04',
#  'vc_elight_cheer_c05',
#  'vc_elight_cheer_c06',
#  'vc_elight_cheer_c07',
#  'se_falco',
#  'vc_falco',
#  'se_falco_c00',
#  'vc_falco_c00',
#  'se_falco_c01',
#  'vc_falco_c01',
#  'se_falco_c02',
#  'vc_falco_c02',
#  'se_falco_c03',
#  'vc_falco_c03',
#  'se_falco_c04',
#  'vc_falco_c04',
#  'se_falco_c05',
#  'vc_falco_c05',
#  'se_falco_c06',
#  'vc_falco_c06',
#  'se_falco_c07',
#  'vc_falco_c07',
#  'vc_falco_cheer',
#  'vc_falco_cheer_c00',
#  'vc_falco_cheer_c01',
#  'vc_falco_cheer_c02',
#  'vc_falco_cheer_c03',
#  'vc_falco_cheer_c04',
#  'vc_falco_cheer_c05',
#  'vc_falco_cheer_c06',
#  'vc_falco_cheer_c07',
#  'se_fox',
#  'vc_fox',
#  'se_fox_c00',
#  'vc_fox_c00',
#  'se_fox_c01',
#  'vc_fox_c01',
#  'se_fox_c02',
#  'vc_fox_c02',
#  'se_fox_c03',
#  'vc_fox_c03',
#  'se_fox_c04',
#  'vc_fox_c04',
#  'se_fox_c05',
#  'vc_fox_c05',
#  'se_fox_c06',
#  'vc_fox_c06',
#  'se_fox_c07',
#  'vc_fox_c07',
#  'vc_fox_cheer',
#  'vc_fox_cheer_c00',
#  'vc_fox_cheer_c01',
#  'vc_fox_cheer_c02',
#  'vc_fox_cheer_c03',
#  'vc_fox_cheer_c04',
#  'vc_fox_cheer_c05',
#  'vc_fox_cheer_c06',
#  'vc_fox_cheer_c07',
#  'se_gamewatch',
#  'vc_gamewatch',
#  'se_gamewatch_c00',
#  'vc_gamewatch_c00',
#  'se_gamewatch_c01',
#  'vc_gamewatch_c01',
#  'se_gamewatch_c02',
#  'vc_gamewatch_c02',
#  'se_gamewatch_c03',
#  'vc_gamewatch_c03',
#  'se_gamewatch_c04',
#  'vc_gamewatch_c04',
#  'se_gamewatch_c05',
#  'vc_gamewatch_c05',
#  'se_gamewatch_c06',
#  'vc_gamewatch_c06',
#  'se_gamewatch_c07',
#  'vc_gamewatch_c07',
#  'vc_gamewatch_cheer',
#  'vc_gamewatch_cheer_c00',
#  'vc_gamewatch_cheer_c01',
#  'vc_gamewatch_cheer_c02',
#  'vc_gamewatch_cheer_c03',
#  'vc_gamewatch_cheer_c04',
#  'vc_gamewatch_cheer_c05',
#  'vc_gamewatch_cheer_c06',
#  'vc_gamewatch_cheer_c07',
#  'se_ganon',
#  'vc_ganon',
#  'se_ganon_c00',
#  'vc_ganon_c00',
#  'se_ganon_c01',
#  'vc_ganon_c01',
#  'se_ganon_c02',
#  'vc_ganon_c02',
#  'se_ganon_c03',
#  'vc_ganon_c03',
#  'se_ganon_c04',
#  'vc_ganon_c04',
#  'se_ganon_c05',
#  'vc_ganon_c05',
#  'se_ganon_c06',
#  'vc_ganon_c06',
#  'se_ganon_c07',
#  'vc_ganon_c07',
#  'vc_ganon_cheer',
#  'vc_ganon_cheer_c00',
#  'vc_ganon_cheer_c01',
#  'vc_ganon_cheer_c02',
#  'vc_ganon_cheer_c03',
#  'vc_ganon_cheer_c04',
#  'vc_ganon_cheer_c05',
#  'vc_ganon_cheer_c06',
#  'vc_ganon_cheer_c07',
#  'se_gaogaen',
#  'vc_gaogaen',
#  'se_gaogaen_c00',
#  'vc_gaogaen_c00',
#  'se_gaogaen_c01',
#  'vc_gaogaen_c01',
#  'se_gaogaen_c02',
#  'vc_gaogaen_c02',
#  'se_gaogaen_c03',
#  'vc_gaogaen_c03',
#  'se_gaogaen_c04',
#  'vc_gaogaen_c04',
#  'se_gaogaen_c05',
#  'vc_gaogaen_c05',
#  'se_gaogaen_c06',
#  'vc_gaogaen_c06',
#  'se_gaogaen_c07',
#  'vc_gaogaen_c07',
#  'vc_gaogaen_cheer',
#  'vc_gaogaen_cheer_c00',
#  'vc_gaogaen_cheer_c01',
#  'vc_gaogaen_cheer_c02',
#  'vc_gaogaen_cheer_c03',
#  'vc_gaogaen_cheer_c04',
#  'vc_gaogaen_cheer_c05',
#  'vc_gaogaen_cheer_c06',
#  'vc_gaogaen_cheer_c07',
#  'vc_gekkouga',
#  'se_gekkouga',
#  'vc_gekkouga_c00',
#  'se_gekkouga_c00',
#  'vc_gekkouga_c01',
#  'se_gekkouga_c01',
#  'vc_gekkouga_c02',
#  'se_gekkouga_c02',
#  'vc_gekkouga_c03',
#  'se_gekkouga_c03',
#  'vc_gekkouga_c04',
#  'se_gekkouga_c04',
#  'vc_gekkouga_c05',
#  'se_gekkouga_c05',
#  'vc_gekkouga_c06',
#  'se_gekkouga_c06',
#  'vc_gekkouga_c07',
#  'se_gekkouga_c07',
#  'vc_gekkouga_cheer',
#  'vc_gekkouga_cheer_c00',
#  'vc_gekkouga_cheer_c01',
#  'vc_gekkouga_cheer_c02',
#  'vc_gekkouga_cheer_c03',
#  'vc_gekkouga_cheer_c04',
#  'vc_gekkouga_cheer_c05',
#  'vc_gekkouga_cheer_c06',
#  'vc_gekkouga_cheer_c07',
#  'se_ike',
#  'vc_ike',
#  'se_ike_c00',
#  'vc_ike_c00',
#  'se_ike_c01',
#  'vc_ike_c01',
#  'se_ike_c02',
#  'vc_ike_c02',
#  'se_ike_c03',
#  'vc_ike_c03',
#  'se_ike_c04',
#  'vc_ike_c04',
#  'se_ike_c05',
#  'vc_ike_c05',
#  'se_ike_c06',
#  'vc_ike_c06',
#  'se_ike_c07',
#  'vc_ike_c07',
#  'vc_ike_cheer',
#  'vc_ike_cheer_c00',
#  'vc_ike_cheer_c01',
#  'vc_ike_cheer_c02',
#  'vc_ike_cheer_c03',
#  'vc_ike_cheer_c04',
#  'vc_ike_cheer_c05',
#  'vc_ike_cheer_c06',
#  'vc_ike_cheer_c07',
#  'se_inkling',
#  'vc_inkling',
#  'se_inkling_c00',
#  'vc_inkling_c00',
#  'se_inkling_c01',
#  'vc_inkling_c01',
#  'se_inkling_c02',
#  'vc_inkling_c02',
#  'se_inkling_c03',
#  'vc_inkling_c03',
#  'se_inkling_c04',
#  'vc_inkling_c04',
#  'se_inkling_c05',
#  'vc_inkling_c05',
#  'se_inkling_c06',
#  'vc_inkling_c06',
#  'se_inkling_c07',
#  'vc_inkling_c07',
#  'vc_inkling_cheer',
#  'vc_inkling_cheer_c00',
#  'vc_inkling_cheer_c01',
#  'vc_inkling_cheer_c02',
#  'vc_inkling_cheer_c03',
#  'vc_inkling_cheer_c04',
#  'vc_inkling_cheer_c05',
#  'vc_inkling_cheer_c06',
#  'vc_inkling_cheer_c07',
#  'vc_jack',
#  'se_jack',
#  'vc_jack_c00',
#  'se_jack_c00',
#  'vc_jack_c01',
#  'se_jack_c01',
#  'vc_jack_c02',
#  'se_jack_c02',
#  'vc_jack_c03',
#  'se_jack_c03',
#  'vc_jack_c04',
#  'se_jack_c04',
#  'vc_jack_c05',
#  'se_jack_c05',
#  'vc_jack_c06',
#  'se_jack_c06',
#  'vc_jack_c07',
#  'se_jack_c07',
#  'vc_jack_cheer',
#  'vc_jack_cheer_c00',
#  'vc_jack_cheer_c01',
#  'vc_jack_cheer_c02',
#  'vc_jack_cheer_c03',
#  'vc_jack_cheer_c04',
#  'vc_jack_cheer_c05',
#  'vc_jack_cheer_c06',
#  'vc_jack_cheer_c07',
#  'vc_jack_result',
#  'vc_jack_result_c00',
#  'vc_jack_result_c01',
#  'vc_jack_result_c02',
#  'vc_jack_result_c03',
#  'vc_jack_result_c04',
#  'vc_jack_result_c05',
#  'vc_jack_result_c06',
#  'vc_jack_result_c07',
#  'se_jack_uniform',
#  'se_kamui',
#  'vc_kamui',
#  'se_kamui_c00',
#  'vc_kamui_c00',
#  'se_kamui_c01',
#  'vc_kamui_c01',
#  'se_kamui_c02',
#  'vc_kamui_c02',
#  'se_kamui_c03',
#  'vc_kamui_c03',
#  'se_kamui_c04',
#  'vc_kamui_c04',
#  'se_kamui_c05',
#  'vc_kamui_c05',
#  'se_kamui_c06',
#  'vc_kamui_c06',
#  'se_kamui_c07',
#  'vc_kamui_c07',
#  'vc_kamui_cheer',
#  'vc_kamui_cheer_c00',
#  'vc_kamui_cheer_c01',
#  'vc_kamui_cheer_c02',
#  'vc_kamui_cheer_c03',
#  'vc_kamui_cheer_c04',
#  'vc_kamui_cheer_c05',
#  'vc_kamui_cheer_c06',
#  'vc_kamui_cheer_c07',
#  'se_ken',
#  'vc_ken',
#  'se_ken_c00',
#  'vc_ken_c00',
#  'se_ken_c01',
#  'vc_ken_c01',
#  'se_ken_c02',
#  'vc_ken_c02',
#  'se_ken_c03',
#  'vc_ken_c03',
#  'se_ken_c04',
#  'vc_ken_c04',
#  'se_ken_c05',
#  'vc_ken_c05',
#  'se_ken_c06',
#  'vc_ken_c06',
#  'se_ken_c07',
#  'vc_ken_c07',
#  'vc_ken_cheer',
#  'vc_ken_cheer_c00',
#  'vc_ken_cheer_c01',
#  'vc_ken_cheer_c02',
#  'vc_ken_cheer_c03',
#  'vc_ken_cheer_c04',
#  'vc_ken_cheer_c05',
#  'vc_ken_cheer_c06',
#  'vc_ken_cheer_c07',
#  'vc_kirby',
#  'se_kirby',
#  'vc_kirby_c00',
#  'se_kirby_c00',
#  'vc_kirby_c01',
#  'se_kirby_c01',
#  'vc_kirby_c02',
#  'se_kirby_c02',
#  'vc_kirby_c03',
#  'se_kirby_c03',
#  'vc_kirby_c04',
#  'se_kirby_c04',
#  'vc_kirby_c05',
#  'se_kirby_c05',
#  'vc_kirby_c06',
#  'se_kirby_c06',
#  'vc_kirby_c07',
#  'se_kirby_c07',
#  'vc_kirby_cheer',
#  'vc_kirby_cheer_c00',
#  'vc_kirby_cheer_c01',
#  'vc_kirby_cheer_c02',
#  'vc_kirby_cheer_c03',
#  'vc_kirby_cheer_c04',
#  'vc_kirby_cheer_c05',
#  'vc_kirby_cheer_c06',
#  'vc_kirby_cheer_c07',
#  'vc_kirby_copy_brave',
#  'vc_kirby_copy_buddy',
#  'vc_kirby_copy_captain',
#  'vc_kirby_copy_chrom',
#  'vc_kirby_copy_cloud',
#  'vc_kirby_copy_dolly',
#  'vc_kirby_copy_donkey',
#  'vc_kirby_copy_edge',
#  'vc_kirby_copy_eflame',
#  'vc_kirby_copy_element',
#  'vc_kirby_copy_elight',
#  'vc_kirby_copy_ganon',
#  'vc_kirby_copy_gaogaen',
#  'vc_kirby_copy_ike',
#  'vc_kirby_copy_jack',
#  'vc_kirby_copy_kamui',
#  'vc_kirby_copy_ken',
#  'vc_kirby_copy_koopa',
#  'vc_kirby_copy_littlemac',
#  'vc_kirby_copy_lucario',
#  'vc_kirby_copy_lucas',
#  'vc_kirby_copy_lucina',
#  'vc_kirby_copy_marth',
#  'vc_kirby_copy_master',
#  'vc_kirby_copy_mewtwo',
#  'vc_kirby_copy_miifighter',
#  'vc_kirby_copy_miigunner',
#  'vc_kirby_copy_miiswordsman',
#  'vc_kirby_copy_ness',
#  'vc_kirby_copy_palutena',
#  'vc_kirby_copy_pfushigisou',
#  'vc_kirby_copy_pichu',
#  'vc_kirby_copy_pikachu',
#  'vc_kirby_copy_pit',
#  'vc_kirby_copy_pitb',
#  'vc_kirby_copy_popo',
#  'vc_kirby_copy_purin',
#  'vc_kirby_copy_pzenigame',
#  'vc_kirby_copy_reflet',
#  'vc_kirby_copy_richter',
#  'vc_kirby_copy_robot',
#  'vc_kirby_copy_roy',
#  'vc_kirby_copy_ryu',
#  'vc_kirby_copy_sheik',
#  'vc_kirby_copy_shulk',
#  'vc_kirby_copy_simon',
#  'vc_kirby_copy_sonic',
#  'vc_kirby_copy_tantan',
#  'vc_kirby_copy_trail',
#  'vc_kirby_copy_wario',
#  'vc_kirby_copy_wiifit',
#  'vc_kirby_copy_yoshi',
#  'vc_kirby_copy_zelda',
#  'vc_koopa',
#  'se_koopa',
#  'vc_koopa_c00',
#  'se_koopa_c00',
#  'vc_koopa_c01',
#  'se_koopa_c01',
#  'vc_koopa_c02',
#  'se_koopa_c02',
#  'vc_koopa_c03',
#  'se_koopa_c03',
#  'vc_koopa_c04',
#  'se_koopa_c04',
#  'vc_koopa_c05',
#  'se_koopa_c05',
#  'vc_koopa_c06',
#  'se_koopa_c06',
#  'vc_koopa_c07',
#  'se_koopa_c07',
#  'vc_koopa_cheer',
#  'vc_koopa_cheer_c00',
#  'vc_koopa_cheer_c01',
#  'vc_koopa_cheer_c02',
#  'vc_koopa_cheer_c03',
#  'vc_koopa_cheer_c04',
#  'vc_koopa_cheer_c05',
#  'vc_koopa_cheer_c06',
#  'vc_koopa_cheer_c07',
#  'se_koopag',
#  'se_koopag_c00',
#  'se_koopag_c01',
#  'se_koopag_c02',
#  'se_koopag_c03',
#  'se_koopag_c04',
#  'se_koopag_c05',
#  'se_koopag_c06',
#  'se_koopag_c07',
#  'se_koopajr',
#  'vc_koopajr',
#  'se_koopajr_c00',
#  'vc_koopajr_c00',
#  'se_koopajr_c01',
#  'vc_koopajr_c01',
#  'vc_koopajr_c01_cheer',
#  'se_koopajr_c02',
#  'vc_koopajr_c02',
#  'vc_koopajr_c02_cheer',
#  'se_koopajr_c03',
#  'vc_koopajr_c03',
#  'vc_koopajr_c03_cheer',
#  'se_koopajr_c04',
#  'vc_koopajr_c04',
#  'vc_koopajr_c04_cheer',
#  'se_koopajr_c05',
#  'vc_koopajr_c05',
#  'vc_koopajr_c05_cheer',
#  'se_koopajr_c06',
#  'vc_koopajr_c06',
#  'vc_koopajr_c06_cheer',
#  'se_koopajr_c07',
#  'vc_koopajr_c07',
#  'vc_koopajr_c07_cheer',
#  'vc_koopajr_cheer',
#  'vc_koopajr_cheer_c00',
#  'vc_koopajr_cheer_c01',
#  'vc_koopajr_cheer_c02',
#  'vc_koopajr_cheer_c03',
#  'vc_koopajr_cheer_c04',
#  'vc_koopajr_cheer_c05',
#  'vc_koopajr_cheer_c06',
#  'vc_koopajr_cheer_c07',
#  'se_krool',
#  'vc_krool',
#  'se_krool_c00',
#  'vc_krool_c00',
#  'se_krool_c01',
#  'vc_krool_c01',
#  'se_krool_c02',
#  'vc_krool_c02',
#  'se_krool_c03',
#  'vc_krool_c03',
#  'se_krool_c04',
#  'vc_krool_c04',
#  'se_krool_c05',
#  'vc_krool_c05',
#  'se_krool_c06',
#  'vc_krool_c06',
#  'se_krool_c07',
#  'vc_krool_c07',
#  'vc_krool_cheer',
#  'vc_krool_cheer_c00',
#  'vc_krool_cheer_c01',
#  'vc_krool_cheer_c02',
#  'vc_krool_cheer_c03',
#  'vc_krool_cheer_c04',
#  'vc_krool_cheer_c05',
#  'vc_krool_cheer_c06',
#  'vc_krool_cheer_c07',
#  'se_link',
#  'vc_link',
#  'se_link_c00',
#  'vc_link_c00',
#  'se_link_c01',
#  'vc_link_c01',
#  'se_link_c02',
#  'vc_link_c02',
#  'se_link_c03',
#  'vc_link_c03',
#  'se_link_c04',
#  'vc_link_c04',
#  'se_link_c05',
#  'vc_link_c05',
#  'se_link_c06',
#  'vc_link_c06',
#  'se_link_c07',
#  'vc_link_c07',
#  'vc_link_cheer',
#  'vc_link_cheer_c00',
#  'vc_link_cheer_c01',
#  'vc_link_cheer_c02',
#  'vc_link_cheer_c03',
#  'vc_link_cheer_c04',
#  'vc_link_cheer_c05',
#  'vc_link_cheer_c06',
#  'vc_link_cheer_c07',
#  'se_littlemac',
#  'vc_littlemac',
#  'se_littlemac_c00',
#  'vc_littlemac_c00',
#  'se_littlemac_c01',
#  'vc_littlemac_c01',
#  'se_littlemac_c02',
#  'vc_littlemac_c02',
#  'se_littlemac_c03',
#  'vc_littlemac_c03',
#  'se_littlemac_c04',
#  'vc_littlemac_c04',
#  'se_littlemac_c05',
#  'vc_littlemac_c05',
#  'vc_littlemac_c06',
#  'se_littlemac_c06',
#  'vc_littlemac_c07',
#  'se_littlemac_c07',
#  'vc_littlemac_cheer',
#  'vc_littlemac_cheer_c00',
#  'vc_littlemac_cheer_c01',
#  'vc_littlemac_cheer_c02',
#  'vc_littlemac_cheer_c03',
#  'vc_littlemac_cheer_c04',
#  'vc_littlemac_cheer_c05',
#  'vc_littlemac_cheer_c06',
#  'vc_littlemac_cheer_c07',
#  'vc_littlemac_wireframe',
#  'se_littlemac_wireframe',
#  'vc_lucario',
#  'se_lucario',
#  'vc_lucario_c00',
#  'se_lucario_c00',
#  'vc_lucario_c01',
#  ...]

# %% [markdown]
# # Most common sounds

# %%
print('Audio clips with the highest amounts of re-use')
pd.Series(len(g) for g in audio_groups).sort_values(ascending=False).head(5)
# Out:
# Audio clips with the highest amounts of re-use
# 607     1100
# 3995     162
# 764      153
# 6589     150
# 6647     125
# dtype: int64

# %%
print('This is an empty audio clip with nothing in it.')
sorted(audio_groups[607])
# Out:
# This is an empty audio clip with nothing in it.
# ['se_cloud_c01---se_cloud_final04_02.idsp',
#  'se_cloud_c01---se_cloud_final06.idsp',
#  'se_cloud_c01---se_cloud_final_swing01.idsp',
#  'se_cloud_c01---se_cloud_final_swing02.idsp',
#  'se_cloud_c01---se_cloud_final_swing03.idsp',
#  'se_cloud_c01_append---se_cloud_final04_02.idsp',
#  'se_cloud_c01_append---se_cloud_final06.idsp',
#  'se_cloud_c01_append---se_cloud_final_swing01.idsp',
#  'se_cloud_c01_append---se_cloud_final_swing02.idsp',
#  'se_cloud_c01_append---se_cloud_final_swing03.idsp',
#  'se_cloud_c03---se_cloud_final04_02.idsp',
#  'se_cloud_c03---se_cloud_final06.idsp',
#  'se_cloud_c03---se_cloud_final_swing01.idsp',
#  'se_cloud_c03---se_cloud_final_swing02.idsp',
#  'se_cloud_c03---se_cloud_final_swing03.idsp',
#  'se_cloud_c05---se_cloud_final04_02.idsp',
#  'se_cloud_c05---se_cloud_final06.idsp',
#  'se_cloud_c05---se_cloud_final_swing01.idsp',
#  'se_cloud_c05---se_cloud_final_swing02.idsp',
#  'se_cloud_c05---se_cloud_final_swing03.idsp',
#  'se_cloud_c07---se_cloud_final04_02.idsp',
#  'se_cloud_c07---se_cloud_final06.idsp',
#  'se_cloud_c07---se_cloud_final_swing01.idsp',
#  'se_cloud_c07---se_cloud_final_swing02.idsp',
#  'se_cloud_c07---se_cloud_final_swing03.idsp',
#  'se_dedede---se_dedede_wad_dead.idsp',
#  'se_dedede_c00---se_dedede_wad_dead.idsp',
#  'se_dedede_c01---se_dedede_wad_dead.idsp',
#  'se_dedede_c02---se_dedede_wad_dead.idsp',
#  'se_dedede_c03---se_dedede_wad_dead.idsp',
#  'se_dedede_c04---se_dedede_wad_dead.idsp',
#  'se_dedede_c05---se_dedede_wad_dead.idsp',
#  'se_dedede_c06---se_dedede_wad_dead.idsp',
#  'se_dedede_c07---se_dedede_wad_dead.idsp',
#  'se_diddy---se_diddy_final02.idsp',
#  'se_diddy---se_diddy_final04.idsp',
#  'se_diddy_c00---se_diddy_final02.idsp',
#  'se_diddy_c00---se_diddy_final04.idsp',
#  'se_diddy_c01---se_diddy_final02.idsp',
#  'se_diddy_c01---se_diddy_final04.idsp',
#  'se_diddy_c02---se_diddy_final02.idsp',
#  'se_diddy_c02---se_diddy_final04.idsp',
#  'se_diddy_c03---se_diddy_final02.idsp',
#  'se_diddy_c03---se_diddy_final04.idsp',
#  'se_diddy_c04---se_diddy_final02.idsp',
#  'se_diddy_c04---se_diddy_final04.idsp',
#  'se_diddy_c05---se_diddy_final02.idsp',
#  'se_diddy_c05---se_diddy_final04.idsp',
#  'se_diddy_c06---se_diddy_final02.idsp',
#  'se_diddy_c06---se_diddy_final04.idsp',
#  'se_diddy_c07---se_diddy_final02.idsp',
#  'se_diddy_c07---se_diddy_final04.idsp',
#  'se_gamewatch---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c00---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c01---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c02---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c03---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c04---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c05---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c06---se_gamewatch_landing01.idsp',
#  'se_gamewatch_c07---se_gamewatch_landing01.idsp',
#  'se_ganon---se_ganon_special_H04.idsp',
#  'se_ganon_c00---se_ganon_special_H04.idsp',
#  'se_ganon_c01---se_ganon_special_H04.idsp',
#  'se_ganon_c02---se_ganon_special_H04.idsp',
#  'se_ganon_c03---se_ganon_special_H04.idsp',
#  'se_ganon_c04---se_ganon_special_H04.idsp',
#  'se_ganon_c05---se_ganon_special_H04.idsp',
#  'se_ganon_c06---se_ganon_special_H04.idsp',
#  'se_ganon_c07---se_ganon_special_H04.idsp',
#  'se_koopag---se_koopag_attackdash.idsp',
#  'se_koopag---se_koopag_catch.idsp',
#  'se_koopag---se_koopag_special_L03.idsp',
#  'se_koopag_c00---se_koopag_attackdash.idsp',
#  'se_koopag_c00---se_koopag_catch.idsp',
#  'se_koopag_c00---se_koopag_special_L03.idsp',
#  'se_koopag_c01---se_koopag_attackdash.idsp',
#  'se_koopag_c01---se_koopag_catch.idsp',
#  'se_koopag_c01---se_koopag_special_L03.idsp',
#  'se_koopag_c02---se_koopag_attackdash.idsp',
#  'se_koopag_c02---se_koopag_catch.idsp',
#  'se_koopag_c02---se_koopag_special_L03.idsp',
#  'se_koopag_c03---se_koopag_attackdash.idsp',
#  'se_koopag_c03---se_koopag_catch.idsp',
#  'se_koopag_c03---se_koopag_special_L03.idsp',
#  'se_koopag_c04---se_koopag_attackdash.idsp',
#  'se_koopag_c04---se_koopag_catch.idsp',
#  'se_koopag_c04---se_koopag_special_L03.idsp',
#  'se_koopag_c05---se_koopag_attackdash.idsp',
#  'se_koopag_c05---se_koopag_catch.idsp',
#  'se_koopag_c05---se_koopag_special_L03.idsp',
#  'se_koopag_c06---se_koopag_attackdash.idsp',
#  'se_koopag_c06---se_koopag_catch.idsp',
#  'se_koopag_c06---se_koopag_special_L03.idsp',
#  'se_koopag_c07---se_koopag_attackdash.idsp',
#  'se_koopag_c07---se_koopag_catch.idsp',
#  'se_koopag_c07---se_koopag_special_L03.idsp',
#  'se_koopajr---se_koopajr_final02.idsp',
#  'se_koopajr_c00---se_koopajr_final02.idsp',
#  'se_koopajr_c01---se_koopajr_final02.idsp',
#  'se_koopajr_c02---se_koopajr_final02.idsp',
#  'se_koopajr_c03---se_koopajr_final02.idsp',
#  'se_koopajr_c04---se_koopajr_final02.idsp',
#  'se_koopajr_c05---se_koopajr_final02.idsp',
#  'se_koopajr_c06---se_koopajr_final02.idsp',
#  'se_koopajr_c07---se_koopajr_final02.idsp',
#  'se_miienemyf---se_miienemyf_escape.idsp',
#  'se_miienemyf---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c00---se_miienemyf_escape.idsp',
#  'se_miienemyf_c00---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c01---se_miienemyf_escape.idsp',
#  'se_miienemyf_c01---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c02---se_miienemyf_escape.idsp',
#  'se_miienemyf_c02---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c03---se_miienemyf_escape.idsp',
#  'se_miienemyf_c03---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c04---se_miienemyf_escape.idsp',
#  'se_miienemyf_c04---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c05---se_miienemyf_escape.idsp',
#  'se_miienemyf_c05---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c06---se_miienemyf_escape.idsp',
#  'se_miienemyf_c06---se_miienemyf_escapeair.idsp',
#  'se_miienemyf_c07---se_miienemyf_escape.idsp',
#  'se_miienemyf_c07---se_miienemyf_escapeair.idsp',
#  'se_miienemys---se_miienemys_escape.idsp',
#  'se_miienemys---se_miienemys_escapeair.idsp',
#  'se_miienemys_c00---se_miienemys_escape.idsp',
#  'se_miienemys_c00---se_miienemys_escapeair.idsp',
#  'se_miienemys_c01---se_miienemys_escape.idsp',
#  'se_miienemys_c01---se_miienemys_escapeair.idsp',
#  'se_miienemys_c02---se_miienemys_escape.idsp',
#  'se_miienemys_c02---se_miienemys_escapeair.idsp',
#  'se_miienemys_c03---se_miienemys_escape.idsp',
#  'se_miienemys_c03---se_miienemys_escapeair.idsp',
#  'se_miienemys_c04---se_miienemys_escape.idsp',
#  'se_miienemys_c04---se_miienemys_escapeair.idsp',
#  'se_miienemys_c05---se_miienemys_escape.idsp',
#  'se_miienemys_c05---se_miienemys_escapeair.idsp',
#  'se_miienemys_c06---se_miienemys_escape.idsp',
#  'se_miienemys_c06---se_miienemys_escapeair.idsp',
#  'se_miienemys_c07---se_miienemys_escape.idsp',
#  'se_miienemys_c07---se_miienemys_escapeair.idsp',
#  'se_pikmin---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c00---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c01---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c02---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c03---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c04---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c05---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c06---se_pikmin_attackhard_S02.idsp',
#  'se_pikmin_c07---se_pikmin_attackhard_S02.idsp',
#  'se_pzenigame---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c00---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c01---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c02---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c03---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c04---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c05---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c06---se_pzenigame_hide_shell.idsp',
#  'se_pzenigame_c07---se_pzenigame_hide_shell.idsp',
#  'se_samusd---se_samusd_appear02.idsp',
#  'se_samusd_c00---se_samusd_appear02.idsp',
#  'se_samusd_c01---se_samusd_appear02.idsp',
#  'se_samusd_c02---se_samusd_appear02.idsp',
#  'se_samusd_c03---se_samusd_appear02.idsp',
#  'se_samusd_c04---se_samusd_appear02.idsp',
#  'se_samusd_c05---se_samusd_appear02.idsp',
#  'se_samusd_c06---se_samusd_appear02.idsp',
#  'se_samusd_c07---se_samusd_appear02.idsp',
#  'se_szerosuit---se_szerosuit_final03.idsp',
#  'se_szerosuit_c00---se_szerosuit_final03.idsp',
#  'se_szerosuit_c01---se_szerosuit_final03.idsp',
#  'se_szerosuit_c02---se_szerosuit_final03.idsp',
#  'se_szerosuit_c03---se_szerosuit_final03.idsp',
#  'se_szerosuit_c04---se_szerosuit_final03.idsp',
#  'se_szerosuit_c05---se_szerosuit_final03.idsp',
#  'se_szerosuit_c06---se_szerosuit_final03.idsp',
#  'se_szerosuit_c07---se_szerosuit_final03.idsp',
#  'se_tantan---se_tantan_silent_01.idsp',
#  'se_tantan_c00---se_tantan_silent_01.idsp',
#  'se_tantan_c01---se_tantan_silent_01.idsp',
#  'se_tantan_c02---se_tantan_silent_01.idsp',
#  'se_tantan_c03---se_tantan_silent_01.idsp',
#  'se_tantan_c04---se_tantan_silent_01.idsp',
#  'se_tantan_c05---se_tantan_silent_01.idsp',
#  'se_tantan_c06---se_tantan_silent_01.idsp',
#  'se_tantan_c07---se_tantan_silent_01.idsp',
#  'se_wario---se_wario_special_N04.idsp',
#  'se_wario_c00---se_wario_special_N04.idsp',
#  'se_wario_c01---se_wario_special_N04.idsp',
#  'se_wario_c02---se_wario_special_N04.idsp',
#  'se_wario_c03---se_wario_special_N04.idsp',
#  'se_wario_c04---se_wario_special_N04.idsp',
#  'se_wario_c05---se_wario_special_N04.idsp',
#  'se_wario_c06---se_wario_special_N04.idsp',
#  'se_wario_c07---se_wario_special_N04.idsp',
#  'se_younglink---se_younglink_special_N02.idsp',
#  'se_younglink_c00---se_younglink_special_N02.idsp',
#  'se_younglink_c01---se_younglink_special_N02.idsp',
#  'se_younglink_c02---se_younglink_special_N02.idsp',
#  'se_younglink_c03---se_younglink_special_N02.idsp',
#  'se_younglink_c04---se_younglink_special_N02.idsp',
#  'se_younglink_c05---se_younglink_special_N02.idsp',
#  'se_younglink_c06---se_younglink_special_N02.idsp',
#  'se_younglink_c07---se_younglink_special_N02.idsp',
#  'vc_bayonetta_c01---vc_bayonetta_throw_F02.idsp',
#  'vc_bayonetta_c03---vc_bayonetta_throw_F02.idsp',
#  'vc_bayonetta_c05---vc_bayonetta_throw_F02.idsp',
#  'vc_bayonetta_c07---vc_bayonetta_throw_F02.idsp',
#  'vc_buddy---vc_buddy_silent.idsp',
#  'vc_dedede_c06---vc_dedede_attack05.idsp',
#  'vc_dedede_c06---vc_dedede_jump01.idsp',
#  'vc_dedede_c07---vc_dedede_appeal01.idsp',
#  'vc_dedede_c07---vc_dedede_attack05.idsp',
#  'vc_dedede_c07---vc_dedede_jump01.idsp',
#  'vc_demon---vc_demon_silent01.idsp',
#  'vc_demon---vc_demon_silent02.idsp',
#  'vc_demon---vc_demon_silent03.idsp',
#  'vc_demon_c00---vc_demon_silent01.idsp',
#  'vc_demon_c00---vc_demon_silent02.idsp',
#  'vc_demon_c00---vc_demon_silent03.idsp',
#  'vc_demon_c01---vc_demon_silent01.idsp',
#  'vc_demon_c01---vc_demon_silent02.idsp',
#  'vc_demon_c01---vc_demon_silent03.idsp',
#  'vc_demon_c02---vc_demon_silent01.idsp',
#  'vc_demon_c02---vc_demon_silent02.idsp',
#  'vc_demon_c02---vc_demon_silent03.idsp',
#  'vc_demon_c03---vc_demon_silent01.idsp',
#  'vc_demon_c03---vc_demon_silent02.idsp',
#  'vc_demon_c03---vc_demon_silent03.idsp',
#  'vc_demon_c04---vc_demon_silent01.idsp',
#  'vc_demon_c04---vc_demon_silent02.idsp',
#  'vc_demon_c04---vc_demon_silent03.idsp',
#  'vc_demon_c05---vc_demon_silent01.idsp',
#  'vc_demon_c05---vc_demon_silent02.idsp',
#  'vc_demon_c05---vc_demon_silent03.idsp',
#  'vc_demon_c06---vc_demon_silent01.idsp',
#  'vc_demon_c06---vc_demon_silent02.idsp',
#  'vc_demon_c06---vc_demon_silent03.idsp',
#  'vc_demon_c07---vc_demon_silent01.idsp',
#  'vc_demon_c07---vc_demon_silent02.idsp',
#  'vc_demon_c07---vc_demon_silent03.idsp',
#  'vc_diddy---vc_diddy_damage01.idsp',
#  'vc_diddy_c00---vc_diddy_damage01.idsp',
#  'vc_diddy_c01---vc_diddy_damage01.idsp',
#  'vc_diddy_c02---vc_diddy_damage01.idsp',
#  'vc_diddy_c03---vc_diddy_damage01.idsp',
#  'vc_diddy_c04---vc_diddy_damage01.idsp',
#  'vc_diddy_c05---vc_diddy_damage01.idsp',
#  'vc_diddy_c06---vc_diddy_damage01.idsp',
#  'vc_diddy_c07---vc_diddy_damage01.idsp',
#  'vc_donkey---vc_donkey_heavyget.idsp',
#  'vc_donkey---vc_donkey_jump02.idsp',
#  'vc_donkey_c00---vc_donkey_heavyget.idsp',
#  'vc_donkey_c00---vc_donkey_jump02.idsp',
#  'vc_donkey_c01---vc_donkey_heavyget.idsp',
#  'vc_donkey_c01---vc_donkey_jump02.idsp',
#  'vc_donkey_c02---vc_donkey_heavyget.idsp',
#  'vc_donkey_c02---vc_donkey_jump02.idsp',
#  'vc_donkey_c03---vc_donkey_heavyget.idsp',
#  'vc_donkey_c03---vc_donkey_jump02.idsp',
#  'vc_donkey_c04---vc_donkey_heavyget.idsp',
#  'vc_donkey_c04---vc_donkey_jump02.idsp',
#  'vc_donkey_c05---vc_donkey_heavyget.idsp',
#  'vc_donkey_c05---vc_donkey_jump02.idsp',
#  'vc_donkey_c06---vc_donkey_heavyget.idsp',
#  'vc_donkey_c06---vc_donkey_jump02.idsp',
#  'vc_donkey_c07---vc_donkey_heavyget.idsp',
#  'vc_donkey_c07---vc_donkey_jump02.idsp',
#  'vc_eflame_c00---vc_element_silent_01.idsp',
#  'vc_eflame_c01---vc_element_silent_01.idsp',
#  'vc_eflame_c02---vc_element_silent_01.idsp',
#  'vc_eflame_c03---vc_element_silent_01.idsp',
#  'vc_eflame_c04---vc_element_silent_01.idsp',
#  'vc_eflame_c05---vc_element_silent_01.idsp',
#  'vc_eflame_c06---vc_element_silent_01.idsp',
#  'vc_eflame_c07---vc_element_silent_01.idsp',
#  'vc_element---vc_element_silent_01.idsp',
#  'vc_element_c00---vc_element_silent_01.idsp',
#  'vc_element_c01---vc_element_silent_01.idsp',
#  'vc_element_c02---vc_element_silent_01.idsp',
#  'vc_element_c03---vc_element_silent_01.idsp',
#  'vc_element_c04---vc_element_silent_01.idsp',
#  'vc_element_c05---vc_element_silent_01.idsp',
#  'vc_element_c06---vc_element_silent_01.idsp',
#  'vc_element_c07---vc_element_silent_01.idsp',
#  'vc_elight_c00---vc_element_silent_01.idsp',
#  'vc_elight_c01---vc_element_silent_01.idsp',
#  'vc_elight_c02---vc_element_silent_01.idsp',
#  'vc_elight_c03---vc_element_silent_01.idsp',
#  'vc_elight_c04---vc_element_silent_01.idsp',
#  'vc_elight_c05---vc_element_silent_01.idsp',
#  'vc_elight_c06---vc_element_silent_01.idsp',
#  'vc_elight_c07---vc_element_silent_01.idsp',
#  'vc_gekkouga---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c00---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c01---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c02---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c03---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c04---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c05---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c06---vc_gekkouga_001.idsp',
#  'vc_gekkouga_c07---vc_gekkouga_001.idsp',
#  'vc_jack---vc_jack_silent_01.idsp',
#  'vc_jack---vc_jack_silent_02.idsp',
#  'vc_jack---vc_jack_silent_03.idsp',
#  'vc_jack_c00---vc_jack_silent_01.idsp',
#  'vc_jack_c00---vc_jack_silent_02.idsp',
#  'vc_jack_c00---vc_jack_silent_03.idsp',
#  'vc_jack_c01---vc_jack_silent_01.idsp',
#  'vc_jack_c01---vc_jack_silent_02.idsp',
#  'vc_jack_c01---vc_jack_silent_03.idsp',
#  'vc_jack_c02---vc_jack_silent_01.idsp',
#  'vc_jack_c02---vc_jack_silent_02.idsp',
#  'vc_jack_c02---vc_jack_silent_03.idsp',
#  'vc_jack_c03---vc_jack_silent_01.idsp',
#  'vc_jack_c03---vc_jack_silent_02.idsp',
#  'vc_jack_c03---vc_jack_silent_03.idsp',
#  'vc_jack_c04---vc_jack_silent_01.idsp',
#  'vc_jack_c04---vc_jack_silent_02.idsp',
#  'vc_jack_c04---vc_jack_silent_03.idsp',
#  'vc_pit_c00---vc_pit_appeal03.idsp',
#  'vc_pit_c01---vc_pit_appeal03.idsp',
#  'vc_pit_c02---vc_pit_appeal03.idsp',
#  'vc_pit_c03---vc_pit_appeal03.idsp',
#  'vc_pit_c04---vc_pit_appeal03.idsp',
#  'vc_pit_c05---vc_pit_appeal03.idsp',
#  'vc_pit_c06---vc_pit_appeal03.idsp',
#  'vc_pit_c07---vc_pit_appeal03.idsp',
#  'vc_plizardon---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c00---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c01---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c02---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c03---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c04---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c05---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c06---vc_plizardon_appeal03.idsp',
#  'vc_plizardon_c07---vc_plizardon_appeal03.idsp',
#  'vc_popo---vc_popo_damage01.idsp',
#  'vc_popo---vc_popo_damagefly01.idsp',
#  'vc_popo---vc_popo_jump01.idsp',
#  'vc_popo_c00---vc_popo_damage01.idsp',
#  'vc_popo_c00---vc_popo_damagefly01.idsp',
#  'vc_popo_c00---vc_popo_jump01.idsp',
#  'vc_popo_c01---vc_popo_damage01.idsp',
#  'vc_popo_c01---vc_popo_damagefly01.idsp',
#  'vc_popo_c01---vc_popo_jump01.idsp',
#  'vc_popo_c02---vc_popo_damage01.idsp',
#  'vc_popo_c02---vc_popo_damagefly01.idsp',
#  'vc_popo_c02---vc_popo_jump01.idsp',
#  'vc_popo_c03---vc_popo_damage01.idsp',
#  'vc_popo_c03---vc_popo_damagefly01.idsp',
#  'vc_popo_c03---vc_popo_jump01.idsp',
#  'vc_popo_c04---vc_nana_damage01.idsp',
#  'vc_popo_c04---vc_nana_damagefly01.idsp',
#  'vc_popo_c04---vc_nana_jump01.idsp',
#  'vc_popo_c05---vc_nana_damage01.idsp',
#  'vc_popo_c05---vc_nana_damagefly01.idsp',
#  'vc_popo_c05---vc_nana_jump01.idsp',
#  'vc_popo_c06---vc_nana_damage01.idsp',
#  'vc_popo_c06---vc_nana_damagefly01.idsp',
#  'vc_popo_c06---vc_nana_jump01.idsp',
#  'vc_popo_c07---vc_nana_damage01.idsp',
#  'vc_popo_c07---vc_nana_damagefly01.idsp',
#  'vc_popo_c07---vc_nana_jump01.idsp',
#  'vc_ptrainer---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c00---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c01---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c02---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c03---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c04---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c05---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c06---vc_ptrainer_knockout.idsp',
#  'vc_ptrainer_c07---vc_ptrainer_knockout.idsp',
#  'vc_purin---vc_purin_010.idsp',
#  'se_pikachu_c07---se_pikachu_final04_08.idsp',
#  'se_pikachu_c07---se_pikachu_final04_09.idsp']

# %%
print('Kazuyas "WHOOSH" sound.')
sorted(audio_groups[764])
# Out:
# Kazuyas "WHOOSH" sound.
# ['se_demon---se_demon_appeal_S01.idsp',
#  'se_demon---se_demon_appeal_S02.idsp',
#  'se_demon---se_demon_appeal_S04.idsp',
#  'se_demon---se_demon_attackair_L01.idsp',
#  'se_demon---se_demon_attackdash01.idsp',
#  'se_demon---se_demon_attackdash02.idsp',
#  'se_demon---se_demon_attacksquat4.idsp',
#  'se_demon---se_demon_attackstand1.idsp',
#  'se_demon---se_demon_attackstand21.idsp',
#  'se_demon---se_demon_attackstand22.idsp',
#  'se_demon---se_demon_attackstep2S_02.idsp',
#  'se_demon---se_demon_swing_short01.idsp',
#  'se_demon---se_demon_swing_short02.idsp',
#  'se_demon---se_demon_throw_b02.idsp',
#  'se_demon---se_demon_throw_b03.idsp',
#  'se_demon---se_demon_throw_catch_swing.idsp',
#  'se_demon---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c00---se_demon_appeal_S01.idsp',
#  'se_demon_c00---se_demon_appeal_S02.idsp',
#  'se_demon_c00---se_demon_appeal_S04.idsp',
#  'se_demon_c00---se_demon_attackair_L01.idsp',
#  'se_demon_c00---se_demon_attackdash01.idsp',
#  'se_demon_c00---se_demon_attackdash02.idsp',
#  'se_demon_c00---se_demon_attacksquat4.idsp',
#  'se_demon_c00---se_demon_attackstand1.idsp',
#  'se_demon_c00---se_demon_attackstand21.idsp',
#  'se_demon_c00---se_demon_attackstand22.idsp',
#  'se_demon_c00---se_demon_attackstep2S_02.idsp',
#  'se_demon_c00---se_demon_swing_short01.idsp',
#  'se_demon_c00---se_demon_swing_short02.idsp',
#  'se_demon_c00---se_demon_throw_b02.idsp',
#  'se_demon_c00---se_demon_throw_b03.idsp',
#  'se_demon_c00---se_demon_throw_catch_swing.idsp',
#  'se_demon_c00---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c01---se_demon_appeal_S01.idsp',
#  'se_demon_c01---se_demon_appeal_S02.idsp',
#  'se_demon_c01---se_demon_appeal_S04.idsp',
#  'se_demon_c01---se_demon_attackair_L01.idsp',
#  'se_demon_c01---se_demon_attackdash01.idsp',
#  'se_demon_c01---se_demon_attackdash02.idsp',
#  'se_demon_c01---se_demon_attacksquat4.idsp',
#  'se_demon_c01---se_demon_attackstand1.idsp',
#  'se_demon_c01---se_demon_attackstand21.idsp',
#  'se_demon_c01---se_demon_attackstand22.idsp',
#  'se_demon_c01---se_demon_attackstep2S_02.idsp',
#  'se_demon_c01---se_demon_swing_short01.idsp',
#  'se_demon_c01---se_demon_swing_short02.idsp',
#  'se_demon_c01---se_demon_throw_b02.idsp',
#  'se_demon_c01---se_demon_throw_b03.idsp',
#  'se_demon_c01---se_demon_throw_catch_swing.idsp',
#  'se_demon_c01---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c02---se_demon_appeal_S01.idsp',
#  'se_demon_c02---se_demon_appeal_S02.idsp',
#  'se_demon_c02---se_demon_appeal_S04.idsp',
#  'se_demon_c02---se_demon_attackair_L01.idsp',
#  'se_demon_c02---se_demon_attackdash01.idsp',
#  'se_demon_c02---se_demon_attackdash02.idsp',
#  'se_demon_c02---se_demon_attacksquat4.idsp',
#  'se_demon_c02---se_demon_attackstand1.idsp',
#  'se_demon_c02---se_demon_attackstand21.idsp',
#  'se_demon_c02---se_demon_attackstand22.idsp',
#  'se_demon_c02---se_demon_attackstep2S_02.idsp',
#  'se_demon_c02---se_demon_swing_short01.idsp',
#  'se_demon_c02---se_demon_swing_short02.idsp',
#  'se_demon_c02---se_demon_throw_b02.idsp',
#  'se_demon_c02---se_demon_throw_b03.idsp',
#  'se_demon_c02---se_demon_throw_catch_swing.idsp',
#  'se_demon_c02---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c03---se_demon_appeal_S01.idsp',
#  'se_demon_c03---se_demon_appeal_S02.idsp',
#  'se_demon_c03---se_demon_appeal_S04.idsp',
#  'se_demon_c03---se_demon_attackair_L01.idsp',
#  'se_demon_c03---se_demon_attackdash01.idsp',
#  'se_demon_c03---se_demon_attackdash02.idsp',
#  'se_demon_c03---se_demon_attacksquat4.idsp',
#  'se_demon_c03---se_demon_attackstand1.idsp',
#  'se_demon_c03---se_demon_attackstand21.idsp',
#  'se_demon_c03---se_demon_attackstand22.idsp',
#  'se_demon_c03---se_demon_attackstep2S_02.idsp',
#  'se_demon_c03---se_demon_swing_short01.idsp',
#  'se_demon_c03---se_demon_swing_short02.idsp',
#  'se_demon_c03---se_demon_throw_b02.idsp',
#  'se_demon_c03---se_demon_throw_b03.idsp',
#  'se_demon_c03---se_demon_throw_catch_swing.idsp',
#  'se_demon_c03---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c04---se_demon_appeal_S01.idsp',
#  'se_demon_c04---se_demon_appeal_S02.idsp',
#  'se_demon_c04---se_demon_appeal_S04.idsp',
#  'se_demon_c04---se_demon_attackair_L01.idsp',
#  'se_demon_c04---se_demon_attackdash01.idsp',
#  'se_demon_c04---se_demon_attackdash02.idsp',
#  'se_demon_c04---se_demon_attacksquat4.idsp',
#  'se_demon_c04---se_demon_attackstand1.idsp',
#  'se_demon_c04---se_demon_attackstand21.idsp',
#  'se_demon_c04---se_demon_attackstand22.idsp',
#  'se_demon_c04---se_demon_attackstep2S_02.idsp',
#  'se_demon_c04---se_demon_swing_short01.idsp',
#  'se_demon_c04---se_demon_swing_short02.idsp',
#  'se_demon_c04---se_demon_throw_b02.idsp',
#  'se_demon_c04---se_demon_throw_b03.idsp',
#  'se_demon_c04---se_demon_throw_catch_swing.idsp',
#  'se_demon_c04---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c05---se_demon_appeal_S01.idsp',
#  'se_demon_c05---se_demon_appeal_S02.idsp',
#  'se_demon_c05---se_demon_appeal_S04.idsp',
#  'se_demon_c05---se_demon_attackair_L01.idsp',
#  'se_demon_c05---se_demon_attackdash01.idsp',
#  'se_demon_c05---se_demon_attackdash02.idsp',
#  'se_demon_c05---se_demon_attacksquat4.idsp',
#  'se_demon_c05---se_demon_attackstand1.idsp',
#  'se_demon_c05---se_demon_attackstand21.idsp',
#  'se_demon_c05---se_demon_attackstand22.idsp',
#  'se_demon_c05---se_demon_attackstep2S_02.idsp',
#  'se_demon_c05---se_demon_swing_short01.idsp',
#  'se_demon_c05---se_demon_swing_short02.idsp',
#  'se_demon_c05---se_demon_throw_b02.idsp',
#  'se_demon_c05---se_demon_throw_b03.idsp',
#  'se_demon_c05---se_demon_throw_catch_swing.idsp',
#  'se_demon_c05---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c06---se_demon_appeal_S01.idsp',
#  'se_demon_c06---se_demon_appeal_S02.idsp',
#  'se_demon_c06---se_demon_appeal_S04.idsp',
#  'se_demon_c06---se_demon_attackair_L01.idsp',
#  'se_demon_c06---se_demon_attackdash01.idsp',
#  'se_demon_c06---se_demon_attackdash02.idsp',
#  'se_demon_c06---se_demon_attacksquat4.idsp',
#  'se_demon_c06---se_demon_attackstand1.idsp',
#  'se_demon_c06---se_demon_attackstand21.idsp',
#  'se_demon_c06---se_demon_attackstand22.idsp',
#  'se_demon_c06---se_demon_attackstep2S_02.idsp',
#  'se_demon_c06---se_demon_swing_short01.idsp',
#  'se_demon_c06---se_demon_swing_short02.idsp',
#  'se_demon_c06---se_demon_throw_b02.idsp',
#  'se_demon_c06---se_demon_throw_b03.idsp',
#  'se_demon_c06---se_demon_throw_catch_swing.idsp',
#  'se_demon_c06---se_demon_throwcommand_swing02.idsp',
#  'se_demon_c07---se_demon_appeal_S01.idsp',
#  'se_demon_c07---se_demon_appeal_S02.idsp',
#  'se_demon_c07---se_demon_appeal_S04.idsp',
#  'se_demon_c07---se_demon_attackair_L01.idsp',
#  'se_demon_c07---se_demon_attackdash01.idsp',
#  'se_demon_c07---se_demon_attackdash02.idsp',
#  'se_demon_c07---se_demon_attacksquat4.idsp',
#  'se_demon_c07---se_demon_attackstand1.idsp',
#  'se_demon_c07---se_demon_attackstand21.idsp',
#  'se_demon_c07---se_demon_attackstand22.idsp',
#  'se_demon_c07---se_demon_attackstep2S_02.idsp',
#  'se_demon_c07---se_demon_swing_short01.idsp',
#  'se_demon_c07---se_demon_swing_short02.idsp',
#  'se_demon_c07---se_demon_throw_b02.idsp',
#  'se_demon_c07---se_demon_throw_b03.idsp',
#  'se_demon_c07---se_demon_throw_catch_swing.idsp',
#  'se_demon_c07---se_demon_throwcommand_swing02.idsp']

# %%
print('Characters with Unique Sounds per Skin')
pd.Series([
    f.split('_', 1)[1].split('---')[0].split('_', 1)[0]
    for f in [[f for f in sorted(g)][0] for g in audio_groups]
    if '_c0' in f
]).value_counts()
# Out:
# Characters with Unique Sounds per Skin
# eflame         305
# koopajr        210
# brave          150
# master          80
# nana            74
# wiifit          55
# reflet          44
# littlemac       43
# ike             43
# kamui           39
# cloud           34
# ptrainer        28
# edge            24
# bayonetta       24
# inkling         22
# demon           20
# packun          11
# pickel           3
# pikmin           1
# jack             1
# murabito         1
# pfushigisou      1
# dtype: int64
